# %%
2+4
# Out:
# 6

# %%
import numpy as np
import pandas as pd

# %%
content = pd.read_csv('DataSheet.csv')

# %%
content
# Out:
#      AlexFast   AlexNormal  AlexSlow    EllenFast         EllenNormal  \
# 0      123.44       168.14    195.15       128.73              156.42
# 1      126.07       236.97    291.43       131.41              149.73
# 2       81.69       123.47     98.38        60.75               85.75
# 3      270.59       393.92    447.58       204.62              315.52
# 4      187.55       346.13    353.71       155.32              205.53
# 5      160.02       204.76    239.18        94.01              131.51
# 6      224.01       266.43    297.75        154.7              258.01
# 7      101.76       141.44    185.77        82.03               61.72
# 8      192.92       260.73    245.86        93.81              113.65
# 9      100.72        81.29    113.31        61.61               66.12
# 10     206.82       288.55    359.78       165.39              253.23
# 11        184       274.23    336.07       117.86              208.75
# ...

# %%
content.head()
# Out:
#   AlexFast AlexNormal AlexSlow EllenFast EllenNormal EllenSlow EliseFast  \
# 0   123.44     168.14   195.15    128.73      156.42     191.8    114.68
# 1   126.07     236.97   291.43    131.41      149.73    217.49    147.74
# 2    81.69     123.47    98.38     60.75       85.75     97.06     78.99
# 3   270.59     393.92   447.58    204.62      315.52    407.65    298.81
# 4   187.55     346.13   353.71    155.32      205.53    350.77    215.96
#
#   EliseNormal EliseSlow MichaelFast  ... PatSlow ConorFast ConorNormal  \
# 0      133.06    235.16       89.73  ...   246.6     83.42       43.31
# 1      126.68    181.25      118.45  ...  186.71     74.99       77.36
# 2       78.28    105.57       80.18  ...  126.73     57.46       41.15
# 3      327.45    465.79      148.27  ...   290.7    195.85      164.22
# 4      246.91    306.96      126.86  ...  381.32    173.46      161.03
#
#   ConorSlow MarianneFast MarianneNormal MarianneSlow GenaFast GenaNormal  \
# ...

# %%
content.loc[0:12,['AlexFast', 'EllenFast', 'EliseFast', 'MichaelFast','PatFast', 'ConorFast', 'MarianneFast', 'GenaFast']]
# Out:
#    AlexFast EllenFast EliseFast MichaelFast PatFast ConorFast MarianneFast  \
# 0    123.44    128.73    114.68       89.73   131.6     83.42         79.4
# 1    126.07    131.41    147.74      118.45  108.73     74.99        96.95
# 2     81.69     60.75     78.99       80.18   51.03     57.46        62.85
# 3    270.59    204.62    298.81      148.27  153.29    195.85       163.16
# 4    187.55    155.32    215.96      126.86  258.84    173.46       139.58
# 5    160.02     94.01    173.43      124.62    98.7     88.85       104.89
# 6    224.01     154.7    251.12       174.5  122.28    140.39       114.91
# 7    101.76     82.03    119.21       71.76      52     40.59        80.33
# 8    192.92     93.81     201.4      106.41  134.65        88        96.65
# 9    100.72     61.61     97.87       44.01   63.11     63.85        57.16
# 10   206.82    165.39    145.77      157.33     106     84.03        121.5
# ...
